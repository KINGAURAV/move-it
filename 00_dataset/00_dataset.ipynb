# %% [markdown]
# # Upload Dataset to Vayu Object Storage

# %%
import os
import boto3

os.environ["AWS_REQUEST_CHECKSUM_CALCULATION"] = "when_required"
os.environ["AWS_RESPONSE_CHECKSUM_VALIDATION"] = "when_required"

AWS_KEY = "<YOUR_S3_AWS_ACCESS_KEY>"
AWS_SECRET = "<YOUR_S3_AWS_SECRET_KEY>"
S3_ENDPOINT = "<YOUR_S3_ENDPOINT>"

# File to upload
LOCAL_FILE = "cropdata.csv"  # The file to upload

# Bucket name
BUCKET = "<YOUR_S3_BUCKET_NAME>"

# S3 destination key (path within the bucket)
S3_KEY = "cropdata.csv"  # You can change this if you want to upload to a folder

# Create S3 client
s3 = boto3.client(
    "s3",
    aws_access_key_id=AWS_KEY,
    aws_secret_access_key=AWS_SECRET,
    endpoint_url=S3_ENDPOINT
)

def upload_file(local_file, bucket, s3_key):
    if not os.path.isfile(local_file):
        print(f"File not found: {local_file}")
        return
    print(f"Uploading {local_file} → s3://{bucket}/{s3_key}")
    s3.upload_file(local_file, bucket, s3_key)
    print("DONE: File uploaded successfully")

upload_file(LOCAL_FILE, BUCKET, S3_KEY)

# %% [markdown]
# # Download Dataset from Vayu Object Storage

# %%
import os
import boto3

os.environ["AWS_REQUEST_CHECKSUM_CALCULATION"] = "when_required"
os.environ["AWS_RESPONSE_CHECKSUM_VALIDATION"] = "when_required"

AWS_KEY = "<YOUR_S3_AWS_ACCESS_KEY>"
AWS_SECRET = "<YOUR_S3_AWS_SECRET_KEY>"
S3_ENDPOINT = "<YOUR_S3_ENDPOINT>"

# Bucket name
BUCKET = "<YOUR_S3_BUCKET_NAME>"

# S3 key (filename in bucket)
S3_KEY = "cropdata.csv"

# Local filename to save to (in current directory)
LOCAL_FILE = "cropdata.csv"

# Create S3 client
s3 = boto3.client(
    "s3",
    aws_access_key_id=AWS_KEY,
    aws_secret_access_key=AWS_SECRET,
    endpoint_url=S3_ENDPOINT
)

def download_file(bucket, s3_key, local_file):
    print(f"Downloading s3://{bucket}/{s3_key} → {local_file}")
    try:
        s3.download_file(bucket, s3_key, local_file)
        print("DONE: File downloaded successfully")
    except Exception as e:
        print(f"Error downloading file: {e}")

download_file(BUCKET, S3_KEY, LOCAL_FILE)
